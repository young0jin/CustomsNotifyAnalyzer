# %% [markdown]
# <a href="https://colab.research.google.com/github/young0jin/CustomsNotifyAnalyzer/blob/main/pdf2csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
# !pip install pdfplumber
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.6 MB/s eta 0:00:00
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (10.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.2 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 41.1 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 53.3 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.4 pypdfium2-4.30.0

# %%
import requests
import pdfplumber
import pandas as pd
import re

# 다운로드할 PDF 파일 URL 및 저장할 파일 이름 설정
url = "https://www.cbp.gov/sites/default/files/2024-09/vol_58_no_38_complete.pdf"
file_name = "vol_58_no_38_complete.pdf"

# PDF 파일 다운로드
response = requests.get(url)
with open(file_name, 'wb') as file:
    file.write(response.content)

# PDF 파일 열기 및 텍스트 추출
documents = []  # 페이지별 텍스트 저장할 리스트
with pdfplumber.open(file_name) as pdf:
    for page_number, page in enumerate(pdf.pages, start=1):
        text = page.extract_text()
        if text:
            # 줄바꿈을 공백으로 변환하고, 여러 줄바꿈은 문단 구분으로 처리
            cleaned_text = re.sub(r'\n+', ' ', text)  # 여러 줄바꿈을 공백으로 변환
            cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # 다중 공백 정리
            cleaned_text = cleaned_text.strip()  # 양쪽 공백 제거

            # 페이지와 함께 텍스트 저장
            documents.append({"page": page_number, "text": cleaned_text})

# DataFrame으로 변환
df = pd.DataFrame(documents)
df
# Out:
#     page                                               text
# 0      1  U.S. Customs and Border Protection ◆ DEPARTMEN...
# 1      2  2 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO....
# 2      3  3 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO....
# 3      4  4 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO....
# 4      5  5 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO....
# ..   ...                                                ...
# 78    80  82 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 79    81  83 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 80    82  84 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 81    83  Index Customs Bulletin and Decisions Vol. 58, ...
# 82    84  Sea Shepherd New Zealand and Sea Shepherd Cons...
#
# [83 rows x 2 columns]

# %%
df.tail(31)
# Out:
#     page                                               text
# 52    53  53 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 53    55  U.S. Court of International Trade ◆ Slip Op. 2...
# 54    56  58 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 55    57  59 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 56    58  60 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 57    59  61 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 58    60  62 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 59    61  63 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 60    62  64 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 61    63  65 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 62    64  66 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 63    65  67 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 64    66  68 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 65    67  69 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 66    68  70 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 67    69  71 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 68    70  72 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 69    71  73 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 70    72  74 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 71    73  75 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 72    74  76 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 73    75  77 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 74    76  78 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 75    77  79 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 76    78  80 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 77    79  81 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 78    80  82 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 79    81  83 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 80    82  84 CUSTOMS BULLETIN AND DECISIONS, VOL. 58, NO...
# 81    83  Index Customs Bulletin and Decisions Vol. 58, ...
# 82    84  Sea Shepherd New Zealand and Sea Shepherd Cons...

# %%
# CSV 파일로 저장
csv_file_name = "extracted_text.csv"
df.to_csv(csv_file_name, index=False)

print(f"CSV 파일 '{csv_file_name}'로 저장되었습니다.")
# Out:
# CSV 파일 'extracted_text.csv'로 저장되었습니다.
